# %%
'''
Date: 2022-09-12 10:27:57
LastEditTime: 2022-09-12 13:39:29
LastEditors: Li Xiang
Description: 
FilePath: /2d.ipynb
'''

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random

from tqdm import trange

import numpy as np
import math


data = []

for i in range(512):
  
  x = random.uniform(-1, 1)
  y = random.uniform(-1, 1)
  
  # value = [x,x*(-1)**i]
  value = [x,y]
  
  # labels = math.sin(value[0]*math.pi*2)+math.sin(value[1]*math.pi*2)
  labels = value[0]*value[0]+value[1]*value[1]
  data.append((value, labels))

x = []
y = []
for i in range(len(data)):
  x.append(data[i][0])
  y.append(data[i][1])

xTensor = torch.Tensor(np.array(x)).cuda()
yTensor = torch.Tensor(np.array(y)).cuda()

# %%
HIDDEN_DIM = 32
HIDDEN_LAYER_NUM = 64


class ResInitLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResInitLinear, self).__init__()
        assert input_dim == output_dim
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.linear.weight = nn.Parameter(
            self.linear.weight+torch.eye(self.input_dim))

    def forward(self, x):
        out = self.linear(x)
        # out = self.act(out+x)
        return out


class Resx1BlockLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Resx1BlockLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.act = nn.ReLU()

    def forward(self, x):
        out = self.linear(x)
        out = self.act(out+x)
        return out


class Resx1BlockLinearBN(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Resx1BlockLinearBN, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.norm = nn.BatchNorm1d(self.output_dim)
        self.act = nn.ReLU()

    def forward(self, x):
        out = self.linear(x)
        out = self.norm(out)
        out = self.act(out+x)
        return out


class ResBlockLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResBlockLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear_1 = nn.Linear(self.input_dim, self.output_dim)
        self.norm_1 = nn.BatchNorm1d(self.output_dim)
        self.act_1 = nn.ReLU()
        self.linear_2 = nn.Linear(self.input_dim, self.output_dim)
        self.norm_2 = nn.BatchNorm1d(self.output_dim)
        self.act_2 = nn.ReLU()

    def forward(self, x):
        out = self.linear_1(x)
        out = self.norm_1(out)
        out = self.act_1(out)
        out = self.linear_2(out)
        out = self.norm_2(out)
        out = self.act_2(out+x)
        return out


class Resx1MLP(torch.nn.Module):
    def __init__(self):
        super(Resx1MLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(Resx1BlockLinear(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class Resx1MLPBN(torch.nn.Module):
    def __init__(self):
        super(Resx1MLPBN, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(Resx1BlockLinearBN(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class ResMLP(torch.nn.Module):
    def __init__(self):
        super(ResMLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM//2
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(ResBlockLinear(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(nn.Linear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class ResInitMLP(torch.nn.Module):
    def __init__(self):
        super(ResInitMLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(ResInitLinear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class MLPBN(torch.nn.Module):
    def __init__(self):
        super(MLPBN, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(nn.Linear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.BatchNorm1d(self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


# model = MLP().cuda()
# model = Resx1MLP().cuda()
# model = Resx1MLPBN().cuda()
model = ResMLP().cuda()
# model = ResInitMLP().cuda()
# model = MLPBN().cuda()

criterion = torch.nn.MSELoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay=1e-2)

batch_size = 64
data_len = yTensor.size()[0]
max_epoch = 1000
for epoch in range(max_epoch):
    batch_cnt = 0
    batch_val = []
    batch_lab = []
    for batch in range(data_len//batch_size):
        values = xTensor[batch*batch_size: (batch+1)*batch_size, ...]
        labels = yTensor[batch*batch_size: (batch+1)*batch_size, ...]
        output = model(values)

        optimizer.zero_grad()

        loss = criterion(output, labels.unsqueeze(1))
        loss.backward()

        optimizer.step()
    if epoch % 10 == 0:
        print("epoch: ", epoch, "loss: ", float(loss))
final_loss = float(loss)
print("final loss: ", final_loss)
print('training finished')
# Out:
# epoch:  0 loss:  0.9772815704345703
# epoch:  10 loss:  0.0045935772359371185
# epoch:  20 loss:  0.0090079540386796
# epoch:  30 loss:  0.004671731032431126
# epoch:  40 loss:  0.051697395741939545
# epoch:  50 loss:  0.006475905887782574
# epoch:  60 loss:  0.003559481119737029
# epoch:  70 loss:  0.0008042354602366686
# epoch:  80 loss:  0.001128763542510569
# epoch:  90 loss:  0.030552592128515244
# epoch:  100 loss:  0.03693196922540665
# epoch:  110 loss:  0.0006714932969771326
# epoch:  120 loss:  9.588782268110663e-05
# epoch:  130 loss:  0.0004007758107036352
# epoch:  140 loss:  0.0030120043084025383
# epoch:  150 loss:  0.004223271273076534
# epoch:  160 loss:  0.00423496775329113
# epoch:  170 loss:  0.0016186609864234924
# epoch:  180 loss:  0.0002524432784412056
# epoch:  190 loss:  0.0023123854771256447
# epoch:  200 loss:  0.03159588575363159
# epoch:  210 loss:  0.00714455172419548
# epoch:  220 loss:  9.298179065808654e-05
# epoch:  230 loss:  4.076142067788169e-05
# epoch:  240 loss:  0.0005659410962834954
# epoch:  250 loss:  0.0069513628259301186
# epoch:  260 loss:  0.011010606773197651
# epoch:  270 loss:  0.0010642220731824636
# epoch:  280 loss:  5.849324224982411e-05
# epoch:  290 loss:  0.0005697064334526658
# epoch:  300 loss:  0.009120169095695019
# epoch:  310 loss:  0.0029025678522884846
# epoch:  320 loss:  8.527800673618913e-05
# epoch:  330 loss:  0.0008134224335663021
# epoch:  340 loss:  0.0020315758883953094
# epoch:  350 loss:  0.0029673310928046703
# epoch:  360 loss:  0.0002190656668972224
# epoch:  370 loss:  0.0016908521065488458
# epoch:  380 loss:  0.0037498630117625
# epoch:  390 loss:  0.012296093627810478
# epoch:  400 loss:  0.0014068710152059793
# epoch:  410 loss:  0.0002413946931483224
# epoch:  420 loss:  0.0006051830714568496
# epoch:  430 loss:  0.0030998135916888714
# epoch:  440 loss:  0.002748337108641863
# epoch:  450 loss:  0.00138076301664114
# epoch:  460 loss:  0.0011444835690781474
# epoch:  470 loss:  0.0008433663751929998
# epoch:  480 loss:  0.0016066282987594604
# epoch:  490 loss:  0.006154118105769157
# epoch:  500 loss:  0.0033777449280023575
# epoch:  510 loss:  7.861977792344987e-05
# epoch:  520 loss:  1.899200287880376e-05
# epoch:  530 loss:  0.0003872237866744399
# epoch:  540 loss:  0.0013700115960091352
# epoch:  550 loss:  0.0005743574001826346
# epoch:  560 loss:  0.0002901135303545743
# epoch:  570 loss:  0.0022741002030670643
# epoch:  580 loss:  0.0006348062306642532
# epoch:  590 loss:  0.0005732963909395039
# epoch:  600 loss:  0.001328475191257894
# epoch:  610 loss:  0.000940792728215456
# epoch:  620 loss:  0.00036816997453570366
# epoch:  630 loss:  0.0002313421427970752
# epoch:  640 loss:  0.0006277368520386517
# epoch:  650 loss:  0.00031204422703012824
# epoch:  660 loss:  0.0007201948901638389
# epoch:  670 loss:  0.0013587893918156624
# epoch:  680 loss:  0.00042499450501054525
# epoch:  690 loss:  0.0006677776109427214
# epoch:  700 loss:  0.0006552522536367178
# epoch:  710 loss:  0.0002764691016636789
# epoch:  720 loss:  0.00033798746881075203
# epoch:  730 loss:  0.0005200000014156103
# epoch:  740 loss:  0.0005363181699067354
# epoch:  750 loss:  0.0008650504751130939
# epoch:  760 loss:  0.0005674363346770406
# epoch:  770 loss:  0.0005703078932128847
# epoch:  780 loss:  0.001107835560105741
# epoch:  790 loss:  0.0005704764043912292
# epoch:  800 loss:  0.0009980180766433477
# epoch:  810 loss:  0.00101091421674937
# epoch:  820 loss:  0.0005022739060223103
# epoch:  830 loss:  0.000827518233563751
# epoch:  840 loss:  0.0005021017277613282
# epoch:  850 loss:  0.0006627753609791398
# epoch:  860 loss:  0.0006780900293961167
# epoch:  870 loss:  0.0010607512667775154
# epoch:  880 loss:  0.0007800674065947533
# epoch:  890 loss:  0.0008916709339246154
# epoch:  900 loss:  0.0007830267422832549
# epoch:  910 loss:  0.0008585057803429663
# epoch:  920 loss:  0.0008884179405868053
# epoch:  930 loss:  0.001194588840007782
# epoch:  940 loss:  0.001244466402567923
# epoch:  950 loss:  0.0008752867579460144
# epoch:  960 loss:  0.0011275304714217782
# epoch:  970 loss:  0.0011038564844056964
# epoch:  980 loss:  0.0013107373379170895
# epoch:  990 loss:  0.0013591561000794172
# final loss:  0.0014308069366961718
# training finished

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from tqdm import trange
X_STEP = 1000
Y_STEP = 1000
val_space = 1
xs = torch.linspace(-val_space, val_space, steps=X_STEP)
ys = torch.linspace(-val_space, val_space, steps=Y_STEP)
grid_x, grid_y = torch.meshgrid(xs, ys)

grid = torch.stack([grid_x, grid_y], dim=-1)
grid = grid.reshape(-1, 2).cpu()
model.eval()
eval_batch_size = X_STEP
out = []
for i in trange(grid.size()[0]//eval_batch_size):
    torch.cuda.empty_cache()
    res = model(grid[i * eval_batch_size:(i+1)*eval_batch_size, ...].cuda())
    res = res.detach().cpu()
    out.append(res)
    pass

out = torch.cat(out, dim=0)
# out = model(grid)

plot_points = torch.cat([grid, out], dim=1)

# for creating a responsive plot
# %matplotlib widget

# importing required libraries

plot_points = plot_points.detach().cpu()
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
surf_points = plot_points.reshape(X_STEP, Y_STEP, 3)
surf_points_x = surf_points[..., 0]
surf_points_y = surf_points[..., 1]
surf_points_z = surf_points[..., 2]
surf_points_z_gt = surf_points_x*surf_points_x+surf_points_y*surf_points_y
surf_points_z_error = surf_points_z-surf_points_z_gt
print('final loss, mean error: ', float(final_loss), float(abs(surf_points_z_error).mean()))
surf = ax.plot_surface(surf_points_x, surf_points_y, surf_points_z, cmap=cm.jet,
                       linewidth=0, antialiased=False)
pass
# Out:
# 100%|██████████| 1000/1000 [00:30<00:00, 33.03it/s]
# /tmp/ipykernel_26751/1100864679.py:37: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# final loss, mean error:  0.0014308069366961718 0.035477135330438614
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
