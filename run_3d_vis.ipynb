# %%
'''
Date: 2022-09-12 10:27:57
LastEditTime: 2022-09-12 13:39:29
LastEditors: Li Xiang
Description: 
FilePath: /2d.ipynb
'''

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random

from tqdm import trange

import numpy as np
import math


data = []

for i in range(256):
  
  x = random.uniform(-1, 1)
  y = random.uniform(-1, 1)
  
  # value = [x,x*(-1)**i]
  value = [x,y]
  
  # labels = math.sin(value[0]*math.pi*2)+math.sin(value[1]*math.pi*2)
  labels = value[0]*value[0]+value[1]*value[1]
  data.append((value, labels))

x = []
y = []
for i in range(len(data)):
  x.append(data[i][0])
  y.append(data[i][1])

xTensor = torch.Tensor(np.array(x)).cuda()
yTensor = torch.Tensor(np.array(y)).cuda()

# %%
HIDDEN_DIM = 32
HIDDEN_LAYER_NUM = 64


class ResInitLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResInitLinear, self).__init__()
        assert input_dim == output_dim
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.linear.weight = nn.Parameter(
            self.linear.weight+torch.eye(self.input_dim))

    def forward(self, x):
        out = self.linear(x)
        # out = self.act(out+x)
        return out


class Resx1BlockLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Resx1BlockLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.act = nn.ReLU()

    def forward(self, x):
        out = self.linear(x)
        out = self.act(out+x)
        return out


class Resx1BlockLinearBN(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Resx1BlockLinearBN, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.norm = nn.BatchNorm1d(self.output_dim)
        self.act = nn.ReLU()

    def forward(self, x):
        out = self.linear(x)
        out = self.norm(out)
        out = self.act(out+x)
        return out


class ResBlockLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResBlockLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear_1 = nn.Linear(self.input_dim, self.output_dim)
        self.norm_1 = nn.BatchNorm1d(self.output_dim)
        self.act_1 = nn.ReLU()
        self.linear_2 = nn.Linear(self.input_dim, self.output_dim)
        self.norm_2 = nn.BatchNorm1d(self.output_dim)
        self.act_2 = nn.ReLU()

    def forward(self, x):
        out = self.linear_1(x)
        out = self.norm_1(out)
        out = self.act_1(out)
        out = self.linear_2(out)
        out = self.norm_2(out)
        out = self.act_2(out+x)
        return out


class Resx1MLP(torch.nn.Module):
    def __init__(self):
        super(Resx1MLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(Resx1BlockLinear(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class Resx1MLPBN(torch.nn.Module):
    def __init__(self):
        super(Resx1MLPBN, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(Resx1BlockLinearBN(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class ResMLP(torch.nn.Module):
    def __init__(self):
        super(ResMLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM//2
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(ResBlockLinear(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(nn.Linear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class ResInitMLP(torch.nn.Module):
    def __init__(self):
        super(ResInitMLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(ResInitLinear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class MLPBN(torch.nn.Module):
    def __init__(self):
        super(MLPBN, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(nn.Linear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.BatchNorm1d(self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


# model = MLP().cuda()
# model = Resx1MLP().cuda()
# model = Resx1MLPBN().cuda()
model = ResMLP().cuda()
# model = ResInitMLP().cuda()
# model = MLPBN().cuda()

criterion = torch.nn.MSELoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay=1e-2)

batch_size = 64
data_len = yTensor.size()[0]
max_epoch = 1000
for epoch in range(max_epoch):
    batch_cnt = 0
    batch_val = []
    batch_lab = []
    for batch in range(data_len//batch_size):
        values = xTensor[batch*batch_size: (batch+1)*batch_size, ...]
        labels = yTensor[batch*batch_size: (batch+1)*batch_size, ...]
        output = model(values)

        optimizer.zero_grad()

        loss = criterion(output, labels.unsqueeze(1))
        loss.backward()

        optimizer.step()
    if epoch % 10 == 0:
        print("epoch: ", epoch, "loss: ", float(loss))
final_loss = float(loss)
print("final loss: ", final_loss)
print('training finished')
# Out:
# epoch:  0 loss:  9.160408020019531
# epoch:  10 loss:  0.04700613021850586
# epoch:  20 loss:  0.0006565313087776303
# epoch:  30 loss:  2.7556900022318587e-05
# epoch:  40 loss:  4.878098479821347e-06
# epoch:  50 loss:  4.064802851644345e-06
# epoch:  60 loss:  0.00018470018403604627
# epoch:  70 loss:  6.885160928504774e-06
# epoch:  80 loss:  2.804042651405325e-06
# epoch:  90 loss:  3.563663995009847e-06
# epoch:  100 loss:  1.0646472219377756e-05
# epoch:  110 loss:  5.784623863291927e-05
# epoch:  120 loss:  5.019941454520449e-05
# epoch:  130 loss:  9.147678611043375e-06
# epoch:  140 loss:  0.000259512074990198
# epoch:  150 loss:  0.00010286773613188416
# epoch:  160 loss:  1.1970252671744674e-05
# epoch:  170 loss:  6.406458396668313e-06
# epoch:  180 loss:  0.00019947291002608836
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 216
#     213     loss = criterion(output, labels.unsqueeze(1))
#     214     loss.backward()
# --> 216     optimizer.step()
#     217 if epoch % 10 == 0:
#     218     print("epoch: ", epoch, "loss: ", float(loss))
#
# File ~/tools/venv/py38torch18/lib/python3.8/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/tools/venv/py38torch18/lib/python3.8/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/tools/venv/py38torch18/lib/python3.8/site-packages/torch/optim/adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File ~/tools/venv/py38torch18/lib/python3.8/site-packages/torch/optim/adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File ~/tools/venv/py38torch18/lib/python3.8/site-packages/torch/optim/adam.py:259, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     256 step_t += 1
#     258 if weight_decay != 0:
# --> 259     grad = grad.add(param, alpha=weight_decay)
#     261 # Decay the first and second moment running average coefficient
#     262 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#
# KeyboardInterrupt:

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from tqdm import trange
X_STEP = 1000
Y_STEP = 1000
val_space = 1
xs = torch.linspace(-val_space, val_space, steps=X_STEP)
ys = torch.linspace(-val_space, val_space, steps=Y_STEP)
grid_x, grid_y = torch.meshgrid(xs, ys)

grid = torch.stack([grid_x, grid_y], dim=-1)
grid = grid.reshape(-1, 2).cpu()
model.eval()
eval_batch_size = X_STEP
out = []
for i in trange(grid.size()[0]//eval_batch_size):
    torch.cuda.empty_cache()
    res = model(grid[i * eval_batch_size:(i+1)*eval_batch_size, ...].cuda())
    res = res.detach().cpu()
    out.append(res)
    pass

out = torch.cat(out, dim=0)
# out = model(grid)

plot_points = torch.cat([grid, out], dim=1)

# for creating a responsive plot
# %matplotlib widget

# importing required libraries

plot_points = plot_points.detach().cpu()
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
surf_points = plot_points.reshape(X_STEP, Y_STEP, 3)
surf_points_x = surf_points[..., 0]
surf_points_y = surf_points[..., 1]
surf_points_z = surf_points[..., 2]
surf_points_z_gt = surf_points_x*surf_points_x+surf_points_y*surf_points_y
surf_points_z = surf_points_z-surf_points_z_gt
print('final loss, mean error: ', float(final_loss), float(abs(surf_points_z).mean()))
surf = ax.plot_surface(surf_points_x, surf_points_y, surf_points_z, cmap=cm.jet,
                       linewidth=0, antialiased=False)
pass
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 79.97it/s]
# /tmp/ipykernel_26751/2752694743.py:37: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# final loss, mean error:  0.0007860387559048831 0.028296250849962234
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
