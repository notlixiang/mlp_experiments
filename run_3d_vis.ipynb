# %%
'''
Date: 2022-09-12 10:27:57
LastEditTime: 2022-09-12 13:39:29
LastEditors: Li Xiang
Description: 
FilePath: /2d.ipynb
'''

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random

from tqdm import trange

import numpy as np
import math


data = []

for i in range(256):
  
  x = random.uniform(-1, 1)
  y = random.uniform(-1, 1)
  
  # value = [x,x*(-1)**i]
  value = [x,y]
  
  # labels = math.sin(value[0]*math.pi*2)+math.sin(value[1]*math.pi*2)
  labels = value[0]*value[0]+value[1]*value[1]
  data.append((value, labels))

x = []
y = []
for i in range(len(data)):
  x.append(data[i][0])
  y.append(data[i][1])

xTensor = torch.Tensor(np.array(x)).cuda()
yTensor = torch.Tensor(np.array(y)).cuda()

# %%
HIDDEN_DIM = 32
HIDDEN_LAYER_NUM = 64


class ResInitLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResInitLinear, self).__init__()
        assert input_dim == output_dim
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.linear.weight = nn.Parameter(
            self.linear.weight+torch.eye(self.input_dim))

    def forward(self, x):
        out = self.linear(x)
        # out = self.act(out+x)
        return out


class Resx1BlockLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Resx1BlockLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.act = nn.ReLU()

    def forward(self, x):
        out = self.linear(x)
        out = self.act(out+x)
        return out


class Resx1BlockLinearBN(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Resx1BlockLinearBN, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear = nn.Linear(self.input_dim, self.output_dim)
        self.norm = nn.BatchNorm1d(self.output_dim)
        self.act = nn.ReLU()

    def forward(self, x):
        out = self.linear(x)
        out = self.norm(out)
        out = self.act(out+x)
        return out


class ResBlockLinear(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResBlockLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.linear_1 = nn.Linear(self.input_dim, self.output_dim)
        self.norm_1 = nn.BatchNorm1d(self.output_dim)
        self.act_1 = nn.ReLU()
        self.linear_2 = nn.Linear(self.input_dim, self.output_dim)
        self.norm_2 = nn.BatchNorm1d(self.output_dim)
        self.act_2 = nn.ReLU()

    def forward(self, x):
        out = self.linear_1(x)
        out = self.norm_1(out)
        out = self.act_1(out)
        out = self.linear_2(out)
        out = self.norm_2(out)
        out = self.act_2(out+x)
        return out


class Resx1MLP(torch.nn.Module):
    def __init__(self):
        super(Resx1MLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(Resx1BlockLinear(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class Resx1MLPBN(torch.nn.Module):
    def __init__(self):
        super(Resx1MLPBN, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(Resx1BlockLinearBN(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class ResMLP(torch.nn.Module):
    def __init__(self):
        super(ResMLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM//2
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(ResBlockLinear(self.hidden_dim, self.hidden_dim))
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(nn.Linear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class ResInitMLP(torch.nn.Module):
    def __init__(self):
        super(ResInitMLP, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(ResInitLinear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


class MLPBN(torch.nn.Module):
    def __init__(self):
        super(MLPBN, self).__init__()
        self.input_dim = 2
        self.hidden_dim = HIDDEN_DIM
        self.output_dim = 1
        self.hidden_layer_num = HIDDEN_LAYER_NUM
        self.l1 = nn.Linear(2, 1)
        layers = [nn.Linear(self.input_dim, self.hidden_dim), nn.ReLU()]
        for i in range(self.hidden_layer_num):
          layers.append(nn.Linear(self.hidden_dim, self.hidden_dim))
          layers.append(nn.BatchNorm1d(self.hidden_dim))
          layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim, self.output_dim))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out


# model = MLP().cuda()
# model = Resx1MLP().cuda()
# model = Resx1MLPBN().cuda()
model = ResMLP().cuda()
# model = ResInitMLP().cuda()
# model = MLPBN().cuda()

criterion = torch.nn.MSELoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay=1e-2)

batch_size = 64
data_len = yTensor.size()[0]
max_epoch = 1000
for epoch in range(max_epoch):
    batch_cnt = 0
    batch_val = []
    batch_lab = []
    for batch in range(data_len//batch_size):
        values = xTensor[batch*batch_size: (batch+1)*batch_size, ...]
        labels = yTensor[batch*batch_size: (batch+1)*batch_size, ...]
        output = model(values)

        optimizer.zero_grad()

        loss = criterion(output, labels.unsqueeze(1))
        loss.backward()

        optimizer.step()
    if epoch % 10 == 0:
        print("epoch: ", epoch, "loss: ", float(loss))
final_loss = float(loss)
print("final loss: ", final_loss)
print('training finished')
# Out:
# epoch:  0 loss:  1.911942720413208
# epoch:  10 loss:  0.02048809826374054
# epoch:  20 loss:  0.00030192668782547116
# epoch:  30 loss:  1.3706587196793407e-05
# epoch:  40 loss:  8.71427109814249e-05
# epoch:  50 loss:  0.0005096166860312223
# epoch:  60 loss:  0.0014338954351842403
# epoch:  70 loss:  6.325441063381732e-05
# epoch:  80 loss:  4.958939371135784e-06
# epoch:  90 loss:  0.000185751065146178
# epoch:  100 loss:  0.00081009475979954
# epoch:  110 loss:  4.3254494812572375e-05
# epoch:  120 loss:  6.907749593665358e-06
# epoch:  130 loss:  0.00019907503155991435
# epoch:  140 loss:  0.0002964821469504386
# epoch:  150 loss:  0.00038393744034692645
# epoch:  160 loss:  0.0002894964418374002
# epoch:  170 loss:  0.0001550790184410289
# epoch:  180 loss:  0.0038883588276803493
# epoch:  190 loss:  0.054477985948324203
# epoch:  200 loss:  0.003223039209842682
# epoch:  210 loss:  0.00015593795978929847
# epoch:  220 loss:  4.885009730060119e-06
# epoch:  230 loss:  2.101663085340988e-06
# epoch:  240 loss:  3.167951717841788e-06
# epoch:  250 loss:  4.025896942039253e-06
# epoch:  260 loss:  0.00016362049791496247
# epoch:  270 loss:  3.8258185668382794e-05
# epoch:  280 loss:  4.4014494051225483e-05
# epoch:  290 loss:  2.996110197273083e-05
# epoch:  300 loss:  0.00020246046187821776
# epoch:  310 loss:  0.001215185970067978
# epoch:  320 loss:  0.0007945132674649358
# epoch:  330 loss:  0.0029267724603414536
# epoch:  340 loss:  0.0003033119719475508
# epoch:  350 loss:  0.0003084238851442933
# epoch:  360 loss:  0.00041714339749887586
# epoch:  370 loss:  0.002711149863898754
# epoch:  380 loss:  0.007121735718101263
# epoch:  390 loss:  0.000539228378329426
# epoch:  400 loss:  4.3251431634416804e-05
# epoch:  410 loss:  4.5729343582934234e-06
# epoch:  420 loss:  6.028436473570764e-05
# epoch:  430 loss:  0.0006771096959710121
# epoch:  440 loss:  0.002694188617169857
# epoch:  450 loss:  0.0014221329474821687
# epoch:  460 loss:  0.00037999669439159334
# epoch:  470 loss:  0.0008763042278587818
# epoch:  480 loss:  0.0035884142853319645
# epoch:  490 loss:  0.004049527924507856
# epoch:  500 loss:  0.0034782837610691786
# epoch:  510 loss:  0.000154108798597008
# epoch:  520 loss:  2.6136956876143813e-05
# epoch:  530 loss:  3.615831155912019e-05
# epoch:  540 loss:  0.0003800895647145808
# epoch:  550 loss:  0.005588690750300884
# epoch:  560 loss:  0.001291750930249691
# epoch:  570 loss:  0.0002603459870442748
# epoch:  580 loss:  6.916848360560834e-05
# epoch:  590 loss:  0.0005116043612360954
# epoch:  600 loss:  0.0017921626567840576
# epoch:  610 loss:  0.001130391494370997
# epoch:  620 loss:  0.0005902444827370346
# epoch:  630 loss:  0.00013471221609506756
# epoch:  640 loss:  0.002205652417615056
# epoch:  650 loss:  0.007546796463429928
# epoch:  660 loss:  0.00027671107091009617
# epoch:  670 loss:  3.864211612381041e-05
# epoch:  680 loss:  6.362109706969932e-05
# epoch:  690 loss:  0.0008403759566135705
# epoch:  700 loss:  0.0006333804922178388
# epoch:  710 loss:  0.0006389784393832088
# epoch:  720 loss:  0.0012196442112326622
# epoch:  730 loss:  0.005431918427348137
# epoch:  740 loss:  0.0006142571801319718
# epoch:  750 loss:  0.000167984573636204
# epoch:  760 loss:  8.378140046261251e-05
# epoch:  770 loss:  0.0022496788296848536
# epoch:  780 loss:  0.0011064752470701933
# epoch:  790 loss:  0.0006301498506218195
# epoch:  800 loss:  8.334724407177418e-05
# epoch:  810 loss:  0.0010276575339958072
# epoch:  820 loss:  0.0021065454930067062
# epoch:  830 loss:  0.0006586638046428561
# epoch:  840 loss:  0.0011003933614119887
# epoch:  850 loss:  0.00019717698160093278
# epoch:  860 loss:  7.14900525053963e-05
# epoch:  870 loss:  0.00013091220171190798
# epoch:  880 loss:  0.003265064675360918
# epoch:  890 loss:  0.0007894664304330945
# epoch:  900 loss:  0.00022339372662827373
# epoch:  910 loss:  0.00035880430368706584
# epoch:  920 loss:  0.0002626810746733099
# epoch:  930 loss:  0.00018509564688429236
# epoch:  940 loss:  0.00040075130527839065
# epoch:  950 loss:  0.000714237685315311
# epoch:  960 loss:  0.0006842907168902457
# epoch:  970 loss:  0.0006636244943365455
# epoch:  980 loss:  0.000502888229675591
# epoch:  990 loss:  0.00023755908478051424
# final loss:  0.00023065644199959934
# training finished

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from tqdm import trange
X_STEP = 1000
Y_STEP = 1000
val_space = 1
xs = torch.linspace(-val_space, val_space, steps=X_STEP)
ys = torch.linspace(-val_space, val_space, steps=Y_STEP)
grid_x, grid_y = torch.meshgrid(xs, ys)

grid = torch.stack([grid_x, grid_y], dim=-1)
grid = grid.reshape(-1, 2).cpu()
model.eval()
eval_batch_size = X_STEP
out = []
for i in trange(grid.size()[0]//eval_batch_size):
    torch.cuda.empty_cache()
    res = model(grid[i * eval_batch_size:(i+1)*eval_batch_size, ...].cuda())
    res = res.detach().cpu()
    out.append(res)
    pass

out = torch.cat(out, dim=0)
# out = model(grid)

plot_points = torch.cat([grid, out], dim=1)

# for creating a responsive plot
# %matplotlib widget

# importing required libraries

plot_points = plot_points.detach().cpu()
fig = plt.figure()
ax = Axes3D(fig)

# creating the plot
surf_points = plot_points.reshape(X_STEP, Y_STEP, 3)
surf_points_x = surf_points[..., 0]
surf_points_y = surf_points[..., 1]
surf_points_z = surf_points[..., 2]
surf_points_z_gt = surf_points_x*surf_points_x+surf_points_y*surf_points_y
surf_points_z_error = surf_points_z-surf_points_z_gt
print('final loss, mean error: ', float(final_loss), float(abs(surf_points_z_error).mean()))
surf = ax.plot_surface(surf_points_x, surf_points_y, surf_points_z, cmap=cm.jet,
                       linewidth=0, antialiased=False)
pass
# Out:
# 100%|██████████| 1000/1000 [00:25<00:00, 39.39it/s]
# /tmp/ipykernel_26751/1100864679.py:37: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# final loss, mean error:  0.00023065644199959934 0.14770084619522095
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
